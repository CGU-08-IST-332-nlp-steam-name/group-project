# %% [markdown]
# ## Filters for game scraping by theme
#
# I tried to use the code of this guy
# https://github.com/mmmmmm44/steam_scraping_api/blob/main/scrape_categories/README.md
# Could not really test much but it looks like it might be what we need
# I limited the results and added some timers because steam was already flagging me....
#
#
#
# |   “filter” value    | Description
# | “” (empty)          | The default value of the “filter” field, to display all games on Steam. Usually used with field “sorted_by”=”Released_DESC” to display all games on Steam from the latest release date to the earliest. |
# | “popularnew”        | Corresponds to the “New & Trending” tab
# | “topsellers”        | Corresponds to the “Top Sellers” tab
# | “globaltopsellers”  | Corresponds to the “Global Top Sellers” button next to the “See more:” phrase in the bottom of the list of “TopSellers” tab                                                                            |
# | “popularcomingsoon” | Corresponds to the “Popular Upcoming”

# %%
# Imports and Helper functions

from datetime import datetime
import time
import requests
import pickle
from pathlib import Path
import re

# %%
params = {
    "filter": "topsellers",
    "hidef2p": 1,
    "page": 1,                # to control the page of the returned result, similar to what "cursor" does in scraping reviews of a game
    "json": 1
}

def get_search_results(params):
    req_sr = requests.get(
        "https://store.steampowered.com/search/results/",
        params=params)
    
    if req_sr.status_code != 200:
        print_log(f"Failed to get search results: {req_sr.status_code}")
        return {"items": []}
    
    try:
        search_results = req_sr.json()
    except Exception as e:
        print_log(f"Failed to parse search results: {e}")
        return {"items": []}
    
    return search_results
    
search_results = get_search_results(params)

# %%
def print_log(*args):
    print(f"[{str(datetime.now())[:-3]}] ", end="")
    print(*args)
    
def get_search_results(params):
    req_sr = requests.get(
        "https://store.steampowered.com/search/results/",
        params=params)
    
    if req_sr.status_code != 200:
        print_log(f"Failed to get search results: {req_sr.status_code}")
        return {"items": []}
    
    try:
        search_results = req_sr.json()
    except Exception as e:
        print_log(f"Failed to parse search results: {e}")
        return {"items": []}
    
    return search_results
    
def get_app_details(appid):
    while(True):
        if appid == None:
            print_log("App Id is None.")
            return {}

        appdetails_req = requests.get(
            "https://store.steampowered.com/api/appdetails/",
            params={"appids": appid, "cc": "hk", "l": "english"})        # change the countrycode to the region you are staying with
        
        if appdetails_req.status_code == 200:
            appdetails = appdetails_req.json()
            appdetails = appdetails[str(appid)]
            print_log(f"App Id: {appid} - {appdetails['success']}")
            break

        elif appdetails_req.status_code == 429:
            print_log(f'Too many requests. Sleep for 10 sec')
            time.sleep(10)
            continue

        elif appdetails_req.status_code == 403:
            print_log(f'Forbidden to access. Sleep for 5 min.')
            time.sleep(5 * 60)
            continue

        else:
            print_log("ERROR: status code:", appdetails_req.status_code)
            print_log(f"Error in App Id: {appid}.")
            appdetails = {}
            break

    return appdetails

def safe_sleep():
    time.sleep(random.uniform(1.2, 3.5))

# %%
import random
# Main code

"""session = requests.Session()
session.headers.update({
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
})"""

execute_datetime = datetime.now()


    
search_result_folder_path = Path(f"search_results_{execute_datetime.strftime('%Y%m%d')}")
if not search_result_folder_path.exists():
    search_result_folder_path.mkdir()
    
# a list of filters
params_list = [
    {"filter": "topsellers"},
    {"filter": "globaltopsellers"},
    {"filter": "popularnew"},
    {"filter": "popularcommingsoon"},
    {"filter": "", "specials": 1}
]
page_list = list(range(1, 5))

params_sr_default = {
    "filter": "topsellers",
    "hidef2p": 1,
    "page": 1,            # page is used to go through different parts of the ranking. Each page contains 25 results
    "json": 1
}

for update_param in params_list:

    items_all = []
    if update_param["filter"]:
        filename = f"{update_param['filter']}_{execute_datetime.strftime('%Y%m%d')}.pkl"
        category = update_param["filter"]
    else:
        filename = f"specials_{execute_datetime.strftime('%Y%m%d')}.pkl"
        category = "specials"

    if (search_result_folder_path / filename).exists():
        print_log(f"File {filename} exists. Skip.")
        continue

    for page_no in page_list:
        param = params_sr_default.copy()
        param.update(update_param)
        param["page"] = page_no

        search_results = get_search_results(param)
        safe_sleep()
        print_log(search_results)

        if not search_results:
            continue
        # Limit results to 10
        items = search_results.get("items", [])
        items = items[:5]

        # proprocessing search results to retrieve the appid of the game
        for item in items:
            try:
                item["appid"] = re.search(r"steam/\w+/(\d+)", item["logo"]).group(1)      # the URL can be steam/bundles/{appid} or steam/apps/{appid}
            except Exception as e:
                print_log(f"Failed to extract appid: {e}")
                item["appid"] = None

        # request for game information using appid
        for item in items:
            appid = item["appid"]
            appdetails = get_app_details(appid)
            safe_sleep()
            item["appdetail"] = appdetails
            # Add the category to each item
            item["category"] = category

        items_all.extend(items)

    # save the search results
    with open(search_result_folder_path / filename, "wb") as f:
        pickle.dump(items_all, f)
    print_log(f"Saved {filename}")
# Out:
# [2025-11-20 00:31:00.363] {'desc': '', 'items': [{'name': 'ARC Raiders', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1808500/542a243d39bd7ed791359be9e96c82f419b81475/capsule_sm_120.jpg?t=1762957298'}, {'name': 'Disney Dreamlight Valley', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1401590/91d24f5c0d27a3586167889e4b69f5892d3d3200/capsule_sm_120_alt_assets_3.jpg?t=1763565113'}, {'name': 'Steam Deck', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1675200/capsule_sm_120.jpg?t=1763066602'}, {'name': 'Disney Dreamlight Valley: Wishblossom Ranch', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/3979520/1fa23ad704bc47126866cd1530c55a2a6c3712ec/capsule_sm_120.jpg?t=1763560846'}, {'name': 'Risk of Rain 2', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/632360/capsule_sm_120.jpg?t=1763490165'}, {'name': 'Risk of Rain 2: Alloyed Collective', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2781620/182e8dfd04fd1c8ab5693d1defebf4647cd261ed/capsule_sm_120.jpg?t=1763508164'}, {'name': 'Dispatch', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2592160/925ffa7e3699d5c9c1369be5d4c3369f0e907e00/capsule_sm_120.jpg?t=1763398023'}, {'name': 'Call of Duty®: Black Ops 7', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/3606480/e265efebec95c52bb0c662532a51b6bdf45ccd37/capsule_sm_120.jpg?t=1763166085'}, {'name': 'Clair Obscur: Expedition 33', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1903340/001d4a5d81e4bb9055b789240e78e04ef6e6da38/capsule_sm_120.jpg?t=1762765069'}, {'name': 'Moonlighter 2: The Endless Vault', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2350790/3524524545ff53b6b749e240bd4743345d797a4e/capsule_sm_120.jpg?t=1763560629'}, {'name': 'ARC Raiders - Upgrade to Deluxe Edition', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/3948510/977e4f3d5d1bdd5d60d097bdfd0e44a21dddec71/capsule_sm_120.jpg?t=1761816660'}, {'name': 'Call of Duty®: Black Ops III', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/311210/capsule_sm_120.jpg?t=1748022663'}, {'name': 'KINGDOM HEARTS -HD 1.5+2.5 ReMIX-', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/
 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/952060/capsule_sm_120.jpg?t=1728438347'}, {'name': 'DRAGON QUEST® XI S: Echoes of an Elusive Age™ - Definitive Edition', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1295510/capsule_sm_120.jpg?t=1727228467'}, {'name': 'Morsels', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1719040/a097b3f7c1743a95cdb57e50cbf05cac6e733182/capsule_sm_120.jpg?t=1763474391'}, {'name': 'Is This Seat Taken?', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/3035120/696b420beee45cd3e5e0f9397e0b4525cbce6ff6/capsule_sm_120.jpg?t=1763402396'}, {'name': 'KINGDOM HEARTS III + Re Mind (DLC)', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2552450/capsule_sm_120.jpg?t=1726051317'}, {'name': 'Age of Mythology: Retold', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1934680/296d05f1402b49ef041229b6268fa026b5e627a0/capsule_sm_120.jpg?t=1759256879'}, {'name': 'DYNASTY WARRIORS: ORIGINS', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2384580/1b59148462997497dd63c7915637a4396cff4838/capsule_sm_120.jpg?t=1762914160'}, {'name': 'Resident Evil Village', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1196590/capsule_sm_120.jpg?t=1741142800'}, {'name': 'Rune Factory: Guardians of Azuma', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2864560/3fe915a5095f483da2b079ac8f73d74610f7588c/capsule_sm_120.jpg?t=1763057053'}, {'name': 'Fast Food Simulator', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2916430/capsule_sm_120.jpg?t=1762536253'}, {'name': 'Call of Duty®: Ghosts', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/209160/capsule_sm_120.jpg?t=1748043672'}, {'name': 'Tiny Glade', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2198150/04e34a74d1939044b8ab95afb5144bc4fd841300/capsule_sm_120.jpg?t=1758039258'}, {'name': 'NieR Replicant™ ver.1.22474487139...', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1113560/capsule_sm_120.jpg?t=1758094186'}, {'name': 'Nioh 2 – The Complete Edition', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1325200/capsule_sm_120.jpg?t=1760595713'}, {'name': 'FATAL FURY: City of the Wolves', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2492040/2f3bda199fc31791a81e7567c17ad75582bb2a8a/capsule_sm_120_alt_assets_0.jpg?t=1762809995'}, {'name': 'Unpacking', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/1135690/capsule_sm_120.jpg?t=1758154062'}, {'name': 'Prototype 2', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/115320/capsule_sm_120.jpg?t=1655761001'}, {'name': 'Call of Duty®: WWII', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/476600/capsule_sm_120.jpg?t=1751302904'}, {'name': 'Devil May Cry HD Collection', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/631510/capsule_sm_120.jpg?t=1644282550'}, {'name': 'STORY OF SEASONS: Grand Bazaar', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2508780/ded21dd6f7015bb5916acc4d53d6718cd602d9ec/capsule_sm_120.jpg?t=1763145508'}, {'name': 'Storebound', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/3417410/c07aa2361a1e0f18a5ad531412a820fdc3031827/capsule_sm_120.jpg?t=1763562597'}, {'name': 'Vampire: The Masquerade - Bloodlines', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/2600/capsule_sm_120.jpg?t=1604376441'}, {'name': 'Winter Burrow', 'logo': 'https://shared.fastly.steamstatic.com/store_item_assets/steam/apps/3008740/3e1eb40abe32021284a20ccb87c30656e ...
# [2025-11-20 00:33:39.344] App Id: 952060 - True
# [2025-11-20 00:33:42.820] App Id: 1295510 - True
# [2025-11-20 00:33:44.212] Saved specials_20251120.pkl

# %%
import pickle
from pathlib import Path

# Load all pickled search result files and infer category from filename
data = []

pkl_files = sorted(Path('.').glob('search_results_*/**/*.pkl'))
if not pkl_files:
    print("No pickle files found under 'search_results_*'. If you want to load a specific file, update the path here.")
else:
    for p in pkl_files:
        try:
            with open(p, 'rb') as f:
                items = pickle.load(f)
        except Exception as e:
            print(f"Failed to load {p}: {e}")
            continue

        # Infer category from filename (prefix before first underscore)
        stem = p.stem  # e.g., 'globaltopsellers_20251120'
        if '_' in stem:
            category = stem.split('_')[0]
            if category == '':
                category = 'specials'
        else:
            category = stem or 'unknown'

        # Assign category to each item if not present
        for it in items:
            if not isinstance(it, dict):
                continue
            it.setdefault('category', category)

        data.extend(items)
        print(f"Loaded {len(items)} items from {p.name} as category '{category}'")

print(f"Total items loaded: {len(data)}")
# Out:
# Loaded 20 items from globaltopsellers_20251207.pkl as category 'globaltopsellers'
# Loaded 20 items from popularcommingsoon_20251207.pkl as category 'popularcommingsoon'
# Loaded 20 items from popularnew_20251207.pkl as category 'popularnew'
# Loaded 20 items from specials_20251207.pkl as category 'specials'
# Loaded 20 items from topsellers_20251207.pkl as category 'topsellers'
# Total items loaded: 100

# %%
import pandas as pd

# Extract key information into a clean DataFrame
def create_game_dataframe(data):
    """Convert raw scraped data into a clean, readable DataFrame"""
    games = []
    
    for item in data:
        try:
            appid = item.get("appid")
            appdetail = item.get("appdetail", {})
            filter_category = item.get("category", "Unknown")
            
            # Extract data safely with defaults
            if appdetail and appdetail.get("success"):
                detail_data = appdetail.get("data", {})
                
                # Extract genres - handle both string and dict formats
                genres = detail_data.get("genres", [])
                if genres and isinstance(genres[0], dict):
                    genre_str = ", ".join([g.get("description", "") for g in genres[:3]])
                else:
                    genre_str = ", ".join(genres[:3]) if genres else "N/A"

                # Publishers
                pubs = detail_data.get("publishers", [])
                if isinstance(pubs, list):
                    publishers = ", ".join(pubs) if pubs else "N/A"
                else:
                    publishers = str(pubs) if pubs else "N/A"

                # Categories (distinct from the search filter category)
                cats = detail_data.get("categories", [])
                if cats and isinstance(cats[0], dict):
                    categories = ", ".join([c.get("description", "") for c in cats[:4]])
                else:
                    categories = ", ".join(cats[:4]) if cats else "N/A"

                # Recommendations (total)
                rec = detail_data.get("recommendations", {})
                recommendations = rec.get("total") if isinstance(rec, dict) else (rec or "N/A")
                if recommendations is None:
                    recommendations = "N/A"

                # Required age
                required_age = detail_data.get("required_age", "N/A")

                game_info = {
                    "Filter": filter_category,
                    "App ID": appid,
                    "Name": item.get("name", "N/A"),
                    "Publishers": publishers,
                    "Price": item.get("price", "N/A"),
                    "Release Date": detail_data.get("release_date", {}).get("date", "N/A"),
                    "Genre": genre_str if genre_str else "N/A",
                    "Categories": categories,
                    "Recommendations": recommendations,
                    "Required Age": required_age,
                    "Metacritic Score": detail_data.get("metacritic", {}).get("score", "N/A") if detail_data.get("metacritic") else "N/A",
                }
                games.append(game_info)
        except Exception as e:
            print(f"Error processing item: {e}")
            continue
    
    return pd.DataFrame(games)

# Create and display the DataFrame
df = create_game_dataframe(data)
print(f"\nTotal Games: {len(df)}\n")
print(df.to_string(index=False))


# Optional: Display summary statistics
print("\n" + "="*80)
print("SUMMARY STATISTICS")
print("="*80)
print(f"Games with Metacritic Scores: {df['Metacritic Score'].apply(lambda x: x != 'N/A').sum()}")

# Show breakdown by filter
print("\nBreakdown by Filter:")
filter_counts = df['Filter'].value_counts()
for filter_name, count in filter_counts.items():
Simulation                                 Single-player, Multi-player, Co-op, Online Co-op          816358            0               89
#   globaltopsellers  594570                               Total War: WARHAMMER II SEGA, Feral Interactive (Mac), Feral Interactive (Linux)   N/A 28 Sep, 2017                          Action, Strategy                                     Single-player, Multi-player, PvP, Online PvP           87529            0               87
# popularcommingsoon 1808500                                           ARC Raiders                                           Embark Studios   N/A 30 Oct, 2025                                    Action                                             Multi-player, PvP, Online PvP, Co-op          162016            0              N/A
# popularcommingsoon 1903340                           Clair Obscur: Expedition 33                                       Kepler Interactive   N/A 24 Apr, 2025                               Action, RPG Single-player, Steam Achievements, Full controller support, Adjustable Text Size          142326           18               91
# popularcommingsoon  553850                                         HELLDIVERS™ 2                               PlayStation Publishing LLC   N/A  8 Feb, 2024                                    Action                            Multi-player, Co-op, Online Co-op, Steam Achievements          786796           18              N/A
# popularcommingsoon 2592160                                              Dispatch                                             AdHoc Studio   N/A 22 Oct, 2025                 Action, Adventure, Casual  Single-player, Steam Achievements, Full controller support, Steam Trading Cards          124150            0               89
# popularcommingsoon 1091500                                        Cyberpunk 2077                                           CD PROJEKT RED   N/A  9 Dec, 2020                                       RPG  Single-player, Steam Achievements, Full controller support, Steam Trading Cards          809770           18               86
# popularcommingsoon 1675200                                            Steam Deck                                                      N/A   N/A 17 Jan, 2025                                       N/A                                                                              N/A             N/A            0              N/A
# popularcommingsoon 3932890                                    Escape from Tarkov                                        Battlestate Games   N/A 15 Nov, 2025        Action, Massively Multiplayer, RPG                                               Multi-player, MMO, PvP, Online PvP           33562            0              N/A
# popularcommingsoon  990080                                       Hogwarts Legacy                                       Warner Bros. Games   N/A 10 Feb, 2023                    Action, Adventure, RPG     Single-player, Steam Achievements, Full controller support, In-App Purchases          254552            0               83
# popularcommingsoon 2927200          Mount &amp; Blade II: Bannerlord - War Sails                                 TaleWorlds Entertainment   N/A 26 Nov, 2025                        Action, Indie, RPG  Single-player, Downloadable Content, Steam Workshop, Partial Controller Support            2898            0              N/A
# popularcommingsoon 1623730                                              Palworld                                               Pocketpair   N/A 18 Jan, 2024                  Action, Adventure, Indie                                 Single-player, Multi-player, Co-op, Online Co-op          342274            0              N/A
# popularcommingsoon 1857950                                                  VEIN                                           Ramjet Studios   N/A 24 Oct, 2025                   Action, RPG, Simulation                                     Single-player, Multi-player, PvP, Online PvP            5754            0              N/A
# popularcommingsoon 2753970                                MARVEL Cosmic Invasion                                   Dotemu, Gamirror Games   N/A  1 Dec, 2025                 Action, Adventure, Casual                                 Single-player, Multi-player, Co-op, Online Co-op             811            0              N/A
# popularcommingsoon  266410                                               iRacing              iRacing.com Motorsport Simulations, iRacing   N/A 12 Jan, 2015 Massively Multiplayer, Racing, Simulation                                            Single-player, Multi-player, MMO, PvP            4404            0               79
# popularcommingsoon 2486820                             Sonic Racing: CrossWorlds                                                     SEGA   N/A 25 Sep, 2025                 Action, Adventure, Racing                        Single-player, Multi-player, PvP, Shared/Split Screen PvP            8200            0               85
# popularcommingsoon  518790                          theHunter: Call of the Wild™                                        Avalanche Studios   N/A 16 Feb, 2017             Adventure, Simulation, Sports                                 Single-player, Multi-player, Co-op, Online Co-op          156271            0              N/A
# popularcommingsoon  227300                                Euro Truck Simulator 2                                             SCS Software   N/A 12 Oct, 2012                         Indie, Simulation                                 Single-player, Multi-player, Co-op, Online Co-
  Action, Adventure, Indie                                 Single-player, Multi-player, Co-op, Online Co-op           47763            0              N/A
#         topsellers 2124490                                         SILENT HILL 2                                                   KONAMI   N/A  7 Oct, 2024                         Action, Adventure          Single-player, Steam Achievements, Full controller support, Steam Cloud           34043           18              N/A
#         topsellers  582660                                          Black Desert                                              Pearl Abyss   N/A 14 Sep, 2021  Action, Adventure, Massively Multiplayer                                               Multi-player, MMO, PvP, Online PvP           60567            0               80
#         topsellers 2300320                                  Farming Simulator 25                                          GIANTS Software   N/A 12 Nov, 2024                                Simulation                                 Single-player, Multi-player, Co-op, Online Co-op           28207            0              N/A
#         topsellers 1623730                                              Palworld                                               Pocketpair   N/A 18 Jan, 2024                  Action, Adventure, Indie                                 Single-player, Multi-player, Co-op, Online Co-op          342274            0              N/A
#         topsellers 3450980 Total War: WARHAMMER III - Dechala – Tides of Torment                                  SEGA, Feral Interactive   N/A  4 Dec, 2025                          Action, Strategy                                     Single-player, Multi-player, PvP, Online PvP             185            0              N/A
#         topsellers 1203620                                            Enshrouded                                          Keen Games GmbH   N/A 24 Jan, 2024                  Action, Adventure, Indie                                 Single-player, Multi-player, Co-op, Online Co-op           80304            0              N/A
#         topsellers 1812450                                            Bellwright                             Donkey Crew, Snail Games USA   N/A 23 Apr, 2024                   Action, RPG, Simulation                                 Single-player, Multi-player, Co-op, Online Co-op           13060            0              N/A
#         topsellers 2399830                                ARK: Survival Ascended                         Studio Wildcard, Snail Games USA   N/A 25 Oct, 2023                  Action, Adventure, Indie                                            Single-player, Multi-player, MMO, PvP           80848            0              N/A
#         topsellers  400750                Call to Arms - Gates of Hell: Ostfront                                          Digitalmindsoft   N/A 11 Jun, 2021              Action, Simulation, Strategy                                     Single-player, Multi-player, PvP, Online PvP           26863            0              N/A
#         topsellers 1289670                                               EA Play                                          Electronic Arts   N/A 31 Aug, 2020                            Action, Sports                                     Single-player, Multi-player, PvP, Online PvP             N/A            0              N/A
#
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
# Games with Metacritic Scores: 47
#
# Breakdown by Category:
#   specials: 20 games
#   topsellers: 20 games
#   globaltopsellers: 19 games
#   popularcommingsoon: 19 games
#   popularnew: 19 games

# %%
# Inspect loaded data structure and available fields
from collections import Counter

top_keys = Counter()
detail_keys = Counter()
num_items = len(data)

for it in data:
    if not isinstance(it, dict):
        continue
    for k in it.keys():
        top_keys[k] += 1
    appdetail = it.get('appdetail', {})
    if isinstance(appdetail, dict) and appdetail.get('success'):
        detail = appdetail.get('data', {})
        for k in detail.keys():
            detail_keys[k] += 1

print(f"Total loaded items: {num_items}\n")
print("Top-level keys and how many items have them:")
for k, c in top_keys.most_common():
    print(f"  {k}: {c}")

print("\nNested 'data' keys (in appdetail['data']) and counts:")
for k, c in detail_keys.most_common():
    print(f"  {k}: {c}")

# Show example values for common interesting fields
example_fields = [
    'developers', 'publishers', 'short_description', 'categories',
    'price_overview', 'recommendations', 'metacritic', 'header_image',
    'screenshots', 'languages', 'required_age', 'controller_support'
]

print("\nExample values for commonly useful fields:")
for field in example_fields:
    printed = False
    for it in data:
        appd = it.get('appdetail', {})
        if not (isinstance(appd, dict) and appd.get('success')):
            continue
        d = appd.get('data', {})
        if field in d and d[field]:
            print(f"\n-- {field} (from app id {it.get('appid')}):")
            val = d[field]
            # If it's a long list/dict, print a short summary
            if isinstance(val, list):
                print(f"    list with {len(val)} items; sample: {val[:3]}")
            elif isinstance(val, dict):
                print(f"    dict keys: {list(val.keys())}")
            else:
                print(f"    {val}")
            printed = True
            break
    if not printed:
        print(f"\n-- {field}: (no example found)")

# Suggest additional fields that could be added to the table
suggested = [
    'developers', 'publishers', 'short_description', 'price_overview',
    'recommendations', 'categories', 'metacritic', 'required_age'
]
print("\nSuggested additional columns for the DataFrame:")
print(', '.join(suggested))
# Out:
# Total loaded items: 100
#
# Top-level keys and how many items have them:
#   name: 100
#   logo: 100
#   appid: 100
#   appdetail: 100
#   category: 100
#
# Nested 'data' keys (in appdetail['data']) and counts:
#   type: 97
#   name: 97
#   steam_appid: 97
#   required_age: 97
#   is_free: 97
#   detailed_description: 97
#   about_the_game: 97
#   short_description: 97
#   header_image: 97
#   capsule_image: 97
#   capsule_imagev5: 97
#   website: 97
#   pc_requirements: 97
#   mac_requirements: 97
#   linux_requirements: 97
#   packages: 97
#   package_groups: 97
#   platforms: 97
#   screenshots: 97
#   release_date: 97
#   support_info: 97
#   background: 97
#   background_raw: 97
#   content_descriptors: 97
#   ratings: 97
#   movies: 96
#   supported_languages: 94
#   developers: 94
#   publishers: 94
#   price_overview: 94
#   categories: 94
#   genres: 94
#   recommendations: 93
#   achievements: 83
#   legal_notice: 81
#   dlc: 72
#   controller_support: 53
#   metacritic: 47
#   reviews: 32
#   drm_notice: 20
#   ext_user_account_notice: 12
#   demos: 11
#   fullgame: 2
#
# Example values for commonly useful fields:
#
# -- developers (from app id 1808500):
#     list with 1 items; sample: ['Embark Studios']
#
# -- publishers (from app id 1808500):
#     list with 1 items; sample: ['Embark Studios']
#
# -- short_description (from app id 1675200):
#     Your games, everywhere Powerful, portable PC gaming, designed for comfort and a console-like user experience
#
# -- categories (from app id 1808500):
#     list with 11 items; sample: [{'id': 1, 'description': 'Multi-player'}, {'id': 49, 'description': 'PvP'}, {'id': 36, 'description': 'Online PvP'}]
#
# -- price_overview (from app id 1808500):
#     dict keys: ['currency', 'initial', 'final', 'discount_percent', 'initial_formatted', 'final_formatted']
#
# -- recommendations (from app id 1808500):
#     dict keys: ['total']
#
# -- metacritic (from app id 1903340):
#     dict keys: ['score', 'url']
#
# -- header_image (from app id 1675200):
#     https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/1675200/header.jpg?t=1763066602
#
# -- screenshots (from app id 1675200):
#     list with 5 items; sample: [{'id': 0, 'path_thumbnail': 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/1675200/ss_5535edca3f6c9844d301de3a88ed16a4575376ac.600x338.jpg?t=1763066602', 'path_full': 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/1675200/ss_5535edca3f6c9844d301de3a88ed16a4575376ac.1920x1080.jpg?t=1763066602'}, {'id': 1, 'path_thumbnail': 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/1675200/ss_585b19a7e2eb7e2784c6148fe44782acab73229c.600x338.jpg?t=1763066602', 'path_full': 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/1675200/ss_585b19a7e2eb7e2784c6148fe44782acab73229c.1920x1080.jpg?t=1763066602'}, {'id': 2, 'path_thumbnail': 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/1675200/ss_6d25000e7a7badd44ec9f38e6264c7f400db649c.600x338.jpg?t=1763066602', 'path_full': 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/1675200/ss_6d25000e7a7badd44ec9f38e6264c7f400db649c.1920x1080.jpg?t=1763066602'}]
#
# -- languages: (no example found)
#
# -- required_age (from app id 1903340):
#     18
#
# -- controller_support (from app id 1808500):
#     full
#
# Suggested additional columns for the DataFrame:
# developers, publishers, short_description, price_overview, recommendations, categories, metacritic, required_age
